# %% [markdown]
# References:
# 1. Topic Modeling with Gensim (Python) by Selva Prabhakaran|https://www.machinelearningplus.com/nlp/topic-modeling-gensim-python/#2prerequisitesdownloadnltkstopwordsandspacymodelforlemmatization
# 2. Mallet package:http://mallet.cs.umass.edu/dist/mallet-2.0.8.zip
# 3. What is Topic Coherence by Devashish Deshpande: https://rare-technologies.com/what-is-topic-coherence/#what_is_topic_coherence
# 4. Röder, Michael, Andreas Both, and Alexander Hinneburg. "Exploring the space of topic coherence measures." In Proceedings of the eighth ACM international conference on Web search and data mining, pp. 399-408. 2015, http://svn.aksw.org/papers/2015/WSDM_Topic_Evaluation/public.pdf.

# %%
import os
import pandas as pd
from pandas.core.frame import DataFrame
import random
from random import sample
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()

# %%
#import files
df=pd.read_csv('/Users/hu/Desktop/bookReview2020/genderKirkus/kirkusreviews.tsv',sep='\t')

# %%
df
# Out:
#          idx               docid                      author  \
# 0      40006  mdp.49015000568841                Isaac Asimov
# 1      40013  mdp.49015000750209               robert ward 4
# 2      40014  mdp.49015000753229              tad williams 3
# 3      40022  mdp.49015002778398            stephen hunter 3
# 4      40023  mdp.49015002821123               robert moss 2
# ...      ...                 ...                         ...
# 19013   9989  mdp.39015002996208               Nancy Mitford
# 19014   9991  mdp.39015037392639            charles morgan 4
# 19015   9994  mdp.39015034651441               George Orwell
# 19016   9996        uc1.$b106383  Toshio Mori\nXiaojing Zhou
# 19017   9999        uc1.b4089197             robin maugham 3
#
#                      bookname       orig_auth  \
# 0           ROBOTS AND EMPIRE    Isaac Asimov
# 1                   RED BAKER     Robert Ward
# 2           TAILCHASER'S SONG    Tad Williams
# 3          THE SPANISH GAMBIT  Stephen Hunter
# 4                MOSCOW RULES     Robert Moss
# ...                       ...             ...
# 19013  LOVE IN A COLD CLIMATE   Nancy Mitford
# 19014          THE RIVER LINE  Charles Morgan
# 19015    NINETEEN EIGHTY-FOUR   George Orwell
# 19016     YOKOHAMA CALIFORNIA     Toshio Mori
# 19017             THE SERVANT   Robin Maugham
#
#                                   orig_title           pubdate  \
# 0                          Robots and empire  Sept. 20th, 1985
# 1                                  Red Baker   April 1st, 1985
# 2                          Tailchaser's song   Nov. 21st, 1985
# 3               The Spanish gambit : a novel   July 19th, 1985
# 4                               Moscow rules    Jan. 1st, 1984
# ...                                      ...               ...
# 19013                 Love in a cold climate    July 8th, 1949
# 19014                         The River Line  Sept. 13th, 1949
# 19015          Nineteen eighty-four, a novel   June 13th, 1949
# 19016  Yokohama, California. [Short stories]  March 22nd, 2015
# 19017                            The servant   Feb. 10th, 1949
#
#                     pubname     posted_online kirkus_issue_date  \
# 0                 Doubleday  Sept. 16th, 2011  Sept. 20th, 1985
# 1                 Doubleday                     April 1st, 1985
# 2      New American Library                     Nov. 21st, 1985
# 3                     Crown                     July 19th, 1985
# 4      Villard/Random House                      Jan. 1st, 1984
# ...                     ...               ...               ...
# 19013          Random House   April 4th, 2012    July 8th, 1949
# 19014             Macmillan                    Sept. 13th, 1949
# 19015       Harcourt, Brace    Nov. 2nd, 2011   June 13th, 1949
# 19016   Univ. of Washington    Jan. 7th, 2015  March 22nd, 2015
# 19017       Harcourt, Brace                     Feb. 10th, 1949
#
#                     isbn                                                url  \
# 0             0586062009  https://www.kirkusreviews.com/book-reviews/isa...
# 1                         https://www.kirkusreviews.com/book-reviews/rob...
# 2                         https://www.kirkusreviews.com/book-reviews/tad...
# 3                         https://www.kirkusreviews.com/book-reviews/ste...
# 4                         https://www.kirkusreviews.com/book-reviews/rob...
# ...                  ...                                                ...
# 19013         030774082X  https://www.kirkusreviews.com/book-reviews/nan...
# 19014                     https://www.kirkusreviews.com/book-reviews/cha...
# 19015         0452284236  https://www.kirkusreviews.com/book-reviews/geo...
# 19016  978-0-295-99474-1  https://www.kirkusreviews.com/book-reviews/tos...
# 19017                     https://www.kirkusreviews.com/book-reviews/rob...
#
#                                                   review
# 0      An addition to Asimov's series of robot-detect...
# 1      It's certainly possible to get inside the head...
# 2      A book that may owe its existence to a certain...
# 3      Mock-camp spy thriller set in the Spanish Civi...
# 4      This leisurely, episodic thriller eventually l...
# ...                                                  ...
# 19013  With less of the charm and debonair gaiety of ...
# 19014  I liked this better than anything Morgan has d...
# 19015  The Book-of-the-Month Club dual selection, wit...
# 19016  Originally published in 1949, these 22 stories...
# 19017  A short novel which is a highly skilled portra...
#
# [19018 rows x 13 columns]

# %%
import re
import numpy as np
import pandas as pd
from pprint import pprint

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# spacy for lemmatization
import spacy

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
#stop_words.extend(['from', 'subject', 're', 'edu', 'use'])

# %% [markdown]
# # basic preprocessing

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

# %%
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# %%
# Convert to list
data = df.review.values.tolist()
#pprint(data[:1])

# %%
len(data)
# Out:
# 19018

# %%
data_words = list(sent_to_words(data))
#print(data_words[:1])

# %%
# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  

# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# See trigram example
#print(trigram_mod[bigram_mod[data_words[0]]])

# %%
# Remove Stop Words
data_words_nostops = remove_stopwords(data_words)

# Form Bigrams
data_words_bigrams = make_bigrams(data_words_nostops)

# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
# python3 -m spacy download en
nlp = spacy.load('en', disable=['parser', 'ner'])

# Do lemmatization keeping only noun, adj, vb, adv
data_lemmatized = lemmatization(data_words_bigrams, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])

#print(data_lemmatized[:1])

# %%
id2word = corpora.Dictionary(data_lemmatized)

# Create Corpus
texts = data_lemmatized

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]

# View
#print(corpus[:1])

# %%
id2word[0]
# Out:
# 'abandon'

# %%
# Human readable format of corpus (term-frequency)
[[(id2word[id], freq) for id, freq in cp] for cp in corpus[:1]]
# Out:
# [[('abandon', 1),
#   ('accompany', 1),
#   ('actually', 1),
#   ('addition', 1),
#   ('adjust', 1),
#   ('also', 1),
#   ('ambitious', 1),
#   ('aristocratic', 1),
#   ('backdrop', 1),
#   ('baley', 1),
#   ('begin', 1),
#   ('build', 1),
#   ('case', 1),
#   ('center_stage', 1),
#   ('century', 1),
#   ('colonize', 1),
#   ('convince', 1),
#   ('daneel', 1),
#   ('dawn', 1),
#   ('death', 1),
#   ('decidedly', 1),
#   ('decline', 1),
#   ('defeat', 1),
#   ('dependant', 1),
#   ('destruction', 1),
#   ('disease', 1),
#   ('doing', 1),
#   ('drama', 1),
#   ('dynamic', 1),
#   ('earth', 2),
#   ('effort', 1),
#   ('emotion', 1),
#   ('ensue', 1),
#   ('establish', 1),
#   ('expansion', 1),
#   ('fairly', 1),
#   ('flame', 1),
#   ('former', 1),
#   ('fulminate', 1),
#   ('gladia', 1),
#   ('going', 1),
#   ('grapple', 1),
#   ('grope', 1),
#   ('halt', 1),
#   ('however', 1),
#   ('human', 2),
#   ('impose', 1),
#   ('intertwine', 1),
#   ('investigate', 1),
#   ('law', 1),
#   ('lethal', 1),
#   ('line', 1),
#   ('live', 2),
#   ('long', 2),
#   ('long_ago', 1),
#   ('mar', 1),
#   ('meanwhile', 1),
#   ('mundane', 1),
#   ('nearly', 1),
#   ('novel', 1),
#   ('occupy', 1),
#   ('old', 1),
#   ('ostensibly', 1),
#   ('partner', 1),
#   ('perfunctory', 1),
#   ('pioneer', 1),
#   ('planet', 2),
#   ('plot', 3),
#   ('power', 1),
#   ('read', 1),
#   ('real', 1),
#   ('recently', 1),
#   ('restriction', 1),
#   ('ridden', 1),
#   ('robot', 4),
#   ('robotic', 2),
#   ('romance', 1),
#   ('run', 1),
#   ('satisfy', 1),
#   ('scintillate', 1),
#   ('secretly', 1),
#   ('settler', 3),
#   ('show', 1),
#   ('smart', 1),
#   ('solution', 1),
#   ('spacer', 2),
#   ('standard', 1),
#   ('start', 1),
#   ('still', 1),
#   ('stimulating', 1),
#   ('talky', 1),
#   ('tame', 1),
#   ('team', 1),
#   ('tepid', 1),
#   ('thus', 1),
#   ('transcend', 1),
#   ('unpleasant', 1),
#   ('villain', 1),
#   ('whenever', 1),
#   ('whiz', 1)]]

# %%
# Building LDA Mallet Model
# Download File: http://mallet.cs.umass.edu/dist/mallet-2.0.8.zip
# testing with topic_number=50
mallet_path = '/Users/hu/Desktop/BPO2019fall/BPOtopicModeling/mallet-2.0.8/bin/mallet'# update this path
ldamallet = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=50, id2word=id2word)

# %%
# Show Topics
pprint(ldamallet.show_topics(formatted=False))

# Compute Coherence Score
coherence_model_ldamallet = CoherenceModel(model=ldamallet, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
coherence_ldamallet = coherence_model_ldamallet.get_coherence()
print('\nCoherence Score: ', coherence_ldamallet)
# Out:
# [(36,
#   [('live', 0.04633345494345129),
#    ('life', 0.042259515991730515),
#    ('friend', 0.036817463212939314),
#    ('home', 0.02873039036847866),
#    ('move', 0.02714945883497507),
#    ('job', 0.025750942478414203),
#    ('good', 0.025690137419433295),
#    ('find', 0.025598929830961938),
#    ('work', 0.022893104706311566),
#    ('neighbor', 0.018910373343062142)]),
#  (38,
#   [('make', 0.037521065852650325),
#    ('show', 0.0221946643772457),
#    ('film', 0.01888772298006296),
#    ('movie', 0.017488632388947184),
#    ('real', 0.016312124391872556),
#    ('scene', 0.013990905911157748),
#    ('tv', 0.011415307322967343),
#    ('actor', 0.009920824191548222),
#    ('page', 0.009030493815383636),
#    ('star', 0.008235555979522401)]),
#  (27,
#   [('money', 0.027468330256540836),
#    ('good', 0.024794703673053663),
#    ('work', 0.021898274874275894),
#    ('make', 0.021261697116302755),
#    ('run', 0.02024317270354574),
#    ('sell', 0.016137246164619007),
#    ('set', 0.014322999554395569),
#    ('rich', 0.014036539563307658),
#    ('back', 0.013590935132726462),
#    ('fire', 0.011999490737793621)]),
#  (19,
#   [('turn', 0.025777241171143977),
#    ('drug', 0.020072441895562933),
#    ('dead', 0.01620887413220646),
#    ('shoot', 0.011892544521581647),
#    ('steal', 0.010473890733474192),
#    ('find', 0.009025052822215515),
#    ('call', 0.00884394808330818),
#    ('track', 0.008028976758225174),
#    ('plot', 0.0077573196498641715),
#    ('late', 0.007727135526712949)]),
#  (39,
#   [('story', 0.23128024511067205),
#    ('collection', 0.046931821435730034),
#    ('tale', 0.04555736906909487),
#    ('piece', 0.040260000572688484),
#    ('short', 0.034046330498525325),
#    ('title', 0.02728860636256908),
#    ('good', 0.02124674283423532),
#    ('writer', 0.020845860893966728),
#    ('short_storie', 0.018698279071099274),
#    ('fiction', 0.016665234945451423)]),
#  (30,
#   [('wife', 0.06460632380499122),
#    ('marriage', 0.058478836372289476),
#    ('love', 0.04669978286088224),
#    ('husband', 0.03444480799547875),
#    ('life', 0.03319551444123858),
#    ('affair', 0.032957553764240456),
#    ('child', 0.02248728397632291),
#    ('daughter', 0.021089264998958922),
#    ('woman', 0.019929206698593056),
#    ('divorce', 0.017966031113358517)]),
#  (20,
#   [('mother', 0.036704778657285254),
#    ('die', 0.028437408384637937),
#    ('doctor', 0.027792436235708002),
#    ('baby', 0.027440633245382585),
#    ('child', 0.024684843154500147),
#    ('care', 0.01923189680445617),
#    ('leave', 0.015098211668132513),
#    ('hospital', 0.014101436528877163),
#    ('patient', 0.01404280269715626),
#    ('begin', 0.013954851949574906)]),
#  (11,
#   [('day', 0.04289445383315409),
#    ('night', 0.033154094330926406),
#    ('room', 0.020648333077277616),
#    ('time', 0.01874327853740974),
#    ('spend', 0.015885696727607927),
#    ('house', 0.011123060377938239),
#    ('home', 0.011123060377938239),
#    ('friend', 0.011000153633430635),
#    ('visit', 0.010078353049623599),
#    ('call', 0.009955446305115993)]),
#  (32,
#   [('man', 0.030329318341063026),
#    ('adventure', 0.026492275866671116),
#    ('ship', 0.024490340662640553),
#    ('water', 0.018384438290347336),
#    ('sea', 0.015214707550632279),
#    ('find', 0.015214707550632279),
#    ('rescue', 0.014347202295552367),
#    ('escape', 0.01424710553535084),
#    ('island', 0.013613159387407828),
#    ('day', 0.01094391244870041)]),
#  (44,
#   [('black', 0.07536104142653739),
#    ('white', 0.044613194114855245),
#    ('man', 0.032815784120957356),
#    ('people', 0.02189978981625873),
#    ('color', 0.014170452234049766),
#    ('make', 0.013763644992880873),
#    ('southern', 0.013695843786019391),
#    ('place', 0.01111939792528307),
#    ('race', 0.010949894908129365),
#    ('boy', 0.010712590684114178)])]
#
# Coherence Score:  0.36896646333520633

# %%
# Show Topics
pprint(ldamallet.show_topics(50))
# Out:
# [(0,
#   '0.024*"indian" + 0.020*"dog" + 0.020*"man" + 0.019*"animal" + '
#   '0.015*"native" + 0.015*"land" + 0.014*"people" + 0.012*"wild" + '
#   '0.011*"hunt" + 0.011*"bird"'),
#  (1,
#   '0.192*"woman" + 0.088*"man" + 0.071*"young" + 0.040*"life" + 0.026*"live" + '
#   '0.021*"girl" + 0.019*"love" + 0.015*"husband" + 0.013*"story" + '
#   '0.013*"female"'),
#  (2,
#   '0.112*"find" + 0.052*"man" + 0.033*"back" + 0.029*"dead" + 0.029*"give" + '
#   '0.029*"leave" + 0.028*"year" + 0.028*"search" + 0.024*"bring" + '
#   '0.022*"return"'),
#  (3,
#   '0.059*"story" + 0.056*"character" + 0.043*"people" + 0.040*"book" + '
#   '0.038*"make" + 0.036*"feel" + 0.035*"reader" + 0.030*"life" + 0.027*"give" '
#   '+ 0.022*"sense"'),
#  (4,
#   '0.070*"murder" + 0.043*"case" + 0.038*"mystery" + 0.020*"kill" + '
#   '0.018*"suspect" + 0.014*"find" + 0.014*"crime" + 0.014*"police" + '
#   '0.013*"victim" + 0.013*"death"'),
#  (5,
#   '0.013*"fiction" + 0.011*"half" + 0.011*"work" + 0.010*"dialogue" + '
#   '0.009*"prose" + 0.009*"involve" + 0.009*"familiar" + 0.008*"theme" + '
#   '0.008*"focus" + 0.007*"page"'),
#  (6,
#   '0.026*"rise" + 0.019*"eye" + 0.014*"half" + 0.014*"leave" + 0.013*"kind" + '
#   '0.012*"time" + 0.010*"heart" + 0.009*"back" + 0.009*"moment" + '
#   '0.009*"green"'),
#  (7,
#   '0.021*"year" + 0.016*"social" + 0.013*"early" + 0.011*"french" + '
#   '0.010*"business" + 0.010*"provide" + 0.009*"career" + 0.009*"interest" + '
#   '0.009*"establish" + 0.009*"society"'),
#  (8,
#   '0.024*"experience" + 0.022*"book" + 0.016*"world" + 0.014*"sense" + '
#   '0.014*"deal" + 0.013*"write" + 0.010*"special" + 0.010*"young" + '
#   '0.010*"writer" + 0.010*"talent"'),
#  (9,
#   '0.164*"love" + 0.056*"fall" + 0.036*"young" + 0.030*"girl" + 0.028*"marry" '
#   '+ 0.028*"romance" + 0.025*"meet" + 0.020*"find" + 0.014*"passion" + '
#   '0.014*"lover"'),
#  (10,
#   '0.036*"work" + 0.031*"art" + 0.030*"life" + 0.022*"artist" + 0.017*"age" + '
#   '0.016*"great" + 0.014*"music" + 0.013*"world" + 0.013*"paint" + '
#   '0.013*"live"'),
#  (11,
#   '0.043*"day" + 0.033*"night" + 0.021*"room" + 0.019*"time" + 0.016*"spend" + '
#   '0.011*"house" + 0.011*"home" + 0.011*"friend" + 0.010*"visit" + '
#   '0.010*"call"'),
#  (12,
#   '0.032*"author" + 0.020*"point" + 0.020*"question" + 0.019*"work" + '
#   '0.018*"reader" + 0.016*"mind" + 0.016*"idea" + 0.013*"fact" + 0.012*"view" '
#   '+ 0.011*"interesting"'),
#  (13,
#   '0.073*"boy" + 0.049*"girl" + 0.038*"school" + 0.035*"mother" + '
#   '0.028*"young" + 0.027*"parent" + 0.024*"teacher" + 0.023*"child" + '
#   '0.022*"friend" + 0.021*"student"'),
#  (14,
#   '0.043*"character" + 0.029*"set" + 0.016*"include" + 0.015*"great" + '
#   '0.013*"form" + 0.011*"work" + 0.010*"late" + 0.010*"draw" + 0.010*"full" + '
#   '0.010*"order"'),
#  (15,
#   '0.045*"death" + 0.033*"man" + 0.029*"follow" + 0.019*"young" + '
#   '0.019*"attempt" + 0.018*"time" + 0.015*"suicide" + 0.015*"close" + '
#   '0.014*"die" + 0.012*"fly"'),
#  (16,
#   '0.018*"author" + 0.010*"fiction" + 0.009*"relationship" + 0.009*"character" '
#   '+ 0.009*"story" + 0.007*"protagonist" + 0.007*"experience" + '
#   '0.007*"narrative" + 0.007*"detail" + 0.006*"writer"'),
#  (17,
#   '0.185*"family" + 0.074*"mother" + 0.060*"child" + 0.041*"daughter" + '
#   '0.037*"sister" + 0.037*"son" + 0.031*"brother" + 0.021*"live" + '
#   '0.020*"father" + 0.016*"grow"'),
#  (18,
#   '0.031*"world" + 0.028*"death" + 0.028*"dream" + 0.018*"fear" + '
#   '0.017*"reality" + 0.015*"hope" + 0.011*"despair" + 0.009*"future" + '
#   '0.009*"strange" + 0.008*"image"'),
#  (19,
#   '0.026*"turn" + 0.020*"drug" + 0.016*"dead" + 0.012*"shoot" + 0.010*"steal" '
#   '+ 0.009*"find" + 0.009*"call" + 0.008*"track" + 0.008*"plot" + '
#   '0.008*"late"'),
#  (20,
#   '0.037*"mother" + 0.028*"die" + 0.028*"doctor" + 0.027*"baby" + '
#   '0.025*"child" + 0.019*"care" + 0.015*"leave" + 0.014*"hospital" + '
#   '0.014*"patient" + 0.014*"begin"'),
#  (21,
#   '0.055*"year" + 0.045*"death" + 0.045*"leave" + 0.041*"return" + 0.041*"son" '
#   '+ 0.035*"life" + 0.033*"die" + 0.028*"wife" + 0.026*"home" + 0.022*"day"'),
#  (22,
#   '0.026*"jewish" + 0.020*"faith" + 0.019*"religious" + 0.017*"spiritual" + '
#   '0.015*"priest" + 0.013*"life" + 0.013*"church" + 0.011*"human" + '
#   '0.010*"religion" + 0.010*"follow"'),
#  (23,
#   '0.022*"world" + 0.020*"human" + 0.017*"future" + 0.016*"earth" + '
#   '0.010*"space" + 0.009*"idea" + 0.009*"project" + 0.009*"computer" + '
#   '0.009*"planet" + 0.009*"machine"'),
#  (24,
#   '0.057*"time" + 0.042*"write" + 0.036*"life" + 0.030*"learn" + 0.027*"make" '
#   '+ 0.025*"real" + 0.021*"letter" + 0.019*"long" + 0.018*"read" + '
#   '0.017*"feel"'),
#  (25,
#   '0.020*"bad" + 0.020*"big" + 0.019*"good" + 0.018*"talk" + 0.016*"job" + '
#   '0.016*"run" + 0.015*"car" + 0.014*"thing" + 0.014*"kid" + 0.013*"hard"'),
#  (26,
#   '0.066*"war" + 0.029*"german" + 0.022*"soldier" + 0.018*"officer" + '
#   '0.017*"fight" + 0.016*"battle" + 0.013*"force" + 0.013*"man" + '
#   '0.011*"american" + 0.011*"escape"'),
#  (27,
#   '0.027*"money" + 0.025*"good" + 0.022*"work" + 0.021*"make" + 0.020*"run" + '
#   '0.016*"sell" + 0.014*"set" + 0.014*"rich" + 0.014*"back" + 0.012*"fire"'),
#  (28,
#   '0.025*"character" + 0.018*"turn" + 0.016*"good" + 0.015*"touch" + '
#   '0.013*"long" + 0.012*"bit" + 0.009*"continue" + 0.009*"begin" + '
#   '0.009*"engage" + 0.008*"light"'),
#  (29,
#   '0.058*"write" + 0.043*"book" + 0.027*"literary" + 0.025*"writer" + '
#   '0.022*"publish" + 0.020*"read" + 0.020*"work" + 0.016*"poet" + '
#   '0.016*"author" + 0.014*"style"'),
#  (30,
#   '0.065*"wife" + 0.058*"marriage" + 0.047*"love" + 0.034*"husband" + '
#   '0.033*"life" + 0.033*"affair" + 0.022*"child" + 0.021*"daughter" + '
#   '0.020*"woman" + 0.018*"divorce"'),
#  (31,
#   '0.072*"town" + 0.035*"local" + 0.035*"village" + 0.034*"small" + '
#   '0.026*"people" + 0.021*"country" + 0.019*"place" + 0.019*"farm" + '
#   '0.018*"set" + 0.016*"community"'),
#  (32,
#   '0.030*"man" + 0.026*"adventure" + 0.024*"ship" + 0.018*"water" + '
#   '0.015*"sea" + 0.015*"find" + 0.014*"rescue" + 0.014*"escape" + '
#   '0.014*"island" + 0.011*"day"'),
#  (33,
#   '0.050*"history" + 0.028*"historical" + 0.015*"period" + 0.014*"early" + '
#   '0.013*"great" + 0.013*"event" + 0.012*"figure" + 0.012*"power" + '
#   '0.011*"century" + 0.010*"detail"'),
#  (34,
#   '0.021*"fantasy" + 0.018*"power" + 0.016*"evil" + 0.015*"ghost" + '
#   '0.015*"world" + 0.012*"turn" + 0.011*"ancient" + 0.009*"magic" + '
#   '0.009*"dark" + 0.009*"mysterious"'),
#  (35,
#   '0.051*"story" + 0.020*"part" + 0.018*"bring" + 0.017*"make" + '
#   '0.014*"problem" + 0.013*"personal" + 0.013*"people" + 0.012*"failure" + '
#   '0.012*"provide" + 0.011*"picture"'),
#  (36,
#   '0.046*"live" + 0.042*"life" + 0.037*"friend" + 0.029*"home" + 0.027*"move" '
#   '+ 0.026*"job" + 0.026*"good" + 0.026*"find" + 0.023*"work" + '
#   '0.019*"neighbor"'),
#  (37,
#   '0.041*"narrator" + 0.032*"life" + 0.031*"memory" + 0.019*"move" + '
#   '0.017*"recall" + 0.016*"childhood" + 0.015*"voice" + 0.014*"live" + '
#   '0.013*"begin" + 0.012*"narrative"'),
#  (38,
#   '0.038*"make" + 0.022*"show" + 0.019*"film" + 0.017*"movie" + 0.016*"real" + '
#   '0.014*"scene" + 0.011*"tv" + 0.010*"actor" + 0.009*"page" + 0.008*"star"'),
#  (39,
#   '0.231*"story" + 0.047*"collection" + 0.046*"tale" + 0.040*"piece" + '
#   '0.034*"short" + 0.027*"title" + 0.021*"good" + 0.021*"writer" + '
#   '0.019*"short_storie" + 0.017*"fiction"'),
#  (40,
#   '0.054*"play" + 0.034*"good" + 0.025*"make" + 0.022*"game" + 0.019*"big" + '
#   '0.017*"time" + 0.012*"put" + 0.010*"win" + 0.009*"call" + 0.009*"show"'),
#  (41,
#   '0.035*"sex" + 0.019*"funny" + 0.017*"comic" + 0.016*"sexual" + '
#   '0.015*"comedy" + 0.009*"amusing" + 0.009*"humor" + 0.009*"satire" + '
#   '0.008*"sort" + 0.008*"wife"'),
#  (42,
#   '0.076*"book" + 0.075*"story" + 0.021*"read" + 0.020*"background" + '
#   '0.019*"picture" + 0.018*"good" + 0.016*"market" + 0.012*"quality" + '
#   '0.012*"period" + 0.010*"sale"'),
#  (43,
#   '0.064*"time" + 0.036*"long" + 0.031*"end" + 0.027*"reader" + 0.023*"line" + '
#   '0.016*"hand" + 0.015*"begin" + 0.014*"thing" + 0.014*"close" + '
#   '0.013*"author"'),
#  (44,
#   '0.075*"black" + 0.045*"white" + 0.033*"man" + 0.022*"people" + '
#   '0.014*"color" + 0.014*"make" + 0.014*"southern" + 0.011*"place" + '
#   '0.011*"race" + 0.011*"boy"'),
#  (45,
#   '0.049*"make" + 0.024*"thing" + 0.020*"part" + 0.019*"time" + 0.019*"end" + '
#   '0.019*"clear" + 0.017*"fall" + 0.013*"free" + 0.013*"point" + '
#   '0.012*"finally"'),
#  (46,
#   '0.041*"political" + 0.021*"country" + 0.014*"politic" + 0.014*"state" + '
#   '0.011*"government" + 0.010*"power" + 0.010*"journalist" + 0.009*"personal" '
#   '+ 0.009*"leader" + 0.009*"rule"'),
#  (47,
#   '0.040*"kill" + 0.023*"violence" + 0.020*"rape" + 0.019*"force" + '
#   '0.015*"death" + 0.015*"escape" + 0.015*"brother" + 0.013*"violent" + '
#   '0.013*"murder" + 0.012*"revenge"'),
#  (48,
#   '0.034*"american" + 0.026*"character" + 0.019*"world" + 0.018*"set" + '
#   '0.018*"begin" + 0.016*"culture" + 0.016*"travel" + 0.016*"offer" + '
#   '0.014*"japanese" + 0.014*"chinese"'),
#  (49,
#   '0.022*"plot" + 0.021*"secret" + 0.019*"plan" + 0.016*"agent" + 0.014*"spy" '
#   '+ 0.012*"action" + 0.009*"suspense" + 0.009*"british" + 0.009*"thriller" + '
#   '0.009*"top"')]

# %% [markdown]
# Find the optimized unmber of topics

# %%
def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=3):
    """
    Compute c_v coherence for various number of topics

    Parameters:
    ----------
    dictionary : Gensim dictionary
    corpus : Gensim corpus
    texts : List of input texts
    limit : Max num of topics

    Returns:
    -------
    model_list : List of LDA topic models
    coherence_values : Coherence values corresponding to the LDA model with respective number of topics
    """
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=num_topics, id2word=id2word)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())

    return model_list, coherence_values

# %%
 # Can take a long time to run.
model_list, coherence_values = compute_coherence_values(dictionary=id2word, corpus=corpus, texts=data_lemmatized, start=10, limit=100, step=10)

# %%
# Show graph
limit=100; start=10; step=10;
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

# %%
optimal_model = model_list[7]
model_topics = optimal_model.show_topics(formatted=False)
pprint(optimal_model.print_topics(num_words=10))
# Out:
# [(52,
#   '0.077*"find" + 0.048*"search" + 0.023*"discover" + 0.022*"travel" + '
#   '0.021*"seek" + 0.020*"identity" + 0.018*"truth" + 0.017*"learn" + '
#   '0.016*"meet" + 0.015*"miss"'),
#  (61,
#   '0.045*"brother" + 0.034*"set" + 0.031*"save" + 0.022*"lose" + '
#   '0.022*"return" + 0.022*"escape" + 0.021*"turn" + 0.018*"rescue" + '
#   '0.017*"stone" + 0.015*"gold"'),
#  (76,
#   '0.141*"mother" + 0.081*"family" + 0.045*"sister" + 0.036*"father" + '
#   '0.035*"parent" + 0.032*"daughter" + 0.031*"child" + 0.016*"brother" + '
#   '0.016*"home" + 0.016*"girl"'),
#  (25,
#   '0.063*"make" + 0.053*"city" + 0.034*"side" + 0.033*"time" + 0.025*"catch" + '
#   '0.024*"heart" + 0.018*"back" + 0.018*"read" + 0.017*"end" + 0.017*"set"'),
#  (41,
#   '0.141*"boy" + 0.079*"girl" + 0.068*"young" + 0.032*"grow" + 0.029*"story" + '
#   '0.028*"summer" + 0.023*"age" + 0.022*"adult" + 0.018*"parent" + '
#   '0.017*"grace"'),
#  (69,
#   '0.046*"murder" + 0.030*"case" + 0.027*"lawyer" + 0.027*"kill" + '
#   '0.024*"trial" + 0.023*"prison" + 0.018*"charge" + 0.016*"arrest" + '
#   '0.015*"crime" + 0.013*"law"'),
#  (64,
#   '0.041*"money" + 0.035*"business" + 0.027*"job" + 0.019*"sell" + '
#   '0.019*"company" + 0.017*"big" + 0.017*"pay" + 0.014*"firm" + 0.013*"price" '
#   '+ 0.012*"make"'),
#  (39,
#   '0.059*"dream" + 0.023*"ghost" + 0.019*"light" + 0.017*"gift" + '
#   '0.016*"vision" + 0.016*"haunt" + 0.013*"dark" + 0.013*"watch" + '
#   '0.011*"image" + 0.010*"mind"'),
#  (72,
#   '0.091*"life" + 0.039*"work" + 0.022*"friend" + 0.022*"social" + '
#   '0.021*"character" + 0.019*"draw" + 0.017*"show" + 0.017*"scene" + '
#   '0.017*"make" + 0.016*"lack"'),
#  (73,
#   '0.016*"world" + 0.015*"audience" + 0.014*"experience" + 0.012*"finally" + '
#   '0.010*"special" + 0.010*"attempt" + 0.010*"young" + 0.009*"charm" + '
#   '0.008*"achieve" + 0.008*"assure"'),
#  (46,
#   '0.052*"doctor" + 0.025*"hospital" + 0.025*"patient" + 0.020*"death" + '
#   '0.015*"nurse" + 0.015*"medical" + 0.013*"treatment" + 0.013*"cancer" + '
#   '0.012*"practice" + 0.010*"psychiatrist"'),
#  (53,
#   '0.055*"school" + 0.049*"student" + 0.040*"teacher" + 0.027*"college" + '
#   '0.026*"teach" + 0.024*"class" + 0.018*"professor" + 0.015*"year" + '
#   '0.014*"young" + 0.012*"friend"'),
#  (38,
#   '0.084*"war" + 0.034*"soldier" + 0.027*"officer" + 0.026*"man" + '
#   '0.019*"fight" + 0.016*"military" + 0.016*"battle" + 0.014*"action" + '
#   '0.011*"force" + 0.011*"wound"'),
#  (11,
#   '0.117*"black" + 0.063*"white" + 0.021*"man" + 0.019*"slave" + 0.017*"color" '
#   '+ 0.016*"race" + 0.016*"southern" + 0.015*"african" + 0.014*"people" + '
#   '0.012*"negro"'),
#  (23,
#   '0.031*"faith" + 0.029*"religious" + 0.026*"spiritual" + 0.024*"priest" + '
#   '0.020*"church" + 0.016*"religion" + 0.013*"catholic" + 0.010*"miracle" + '
#   '0.010*"sin" + 0.010*"soul"'),
#  (34,
#   '0.024*"historical" + 0.022*"history" + 0.020*"war" + 0.019*"fight" + '
#   '0.018*"british" + 0.017*"force" + 0.016*"battle" + 0.013*"spanish" + '
#   '0.012*"follow" + 0.011*"capture"'),
#  (26,
#   '0.068*"man" + 0.024*"make" + 0.021*"follow" + 0.019*"great" + '
#   '0.017*"failure" + 0.016*"prove" + 0.016*"success" + 0.015*"lead" + '
#   '0.014*"hold" + 0.014*"build"'),
#  (62,
#   '0.112*"book" + 0.042*"story" + 0.024*"read" + 0.023*"quality" + '
#   '0.019*"picture" + 0.018*"market" + 0.018*"appeal" + 0.014*"reader" + '
#   '0.013*"sell" + 0.012*"people"'),
#  (13,
#   '0.015*"half" + 0.015*"page" + 0.015*"lot" + 0.015*"type" + 0.010*"funny" + '
#   '0.010*"finally" + 0.009*"style" + 0.009*"comic" + 0.008*"hero" + '
#   '0.008*"talk"'),
#  (19,
#   '0.047*"american" + 0.036*"story" + 0.034*"rise" + 0.027*"japanese" + '
#   '0.027*"young" + 0.026*"woman" + 0.026*"world" + 0.023*"chinese" + '
#   '0.020*"learn" + 0.019*"bear"')]

# %%
model_topics = optimal_model.show_topics(formatted=False)
pprint(optimal_model.show_topics(80))
# Out:
# [(0,
#   '0.113*"town" + 0.064*"local" + 0.027*"small" + 0.025*"set" + 0.022*"work" + '
#   '0.019*"fire" + 0.017*"community" + 0.013*"character" + 0.011*"neighbor" + '
#   '0.011*"run"'),
#  (1,
#   '0.034*"show" + 0.030*"film" + 0.028*"movie" + 0.026*"make" + 0.020*"end" + '
#   '0.019*"play" + 0.016*"tv" + 0.016*"actor" + 0.015*"real" + 0.013*"career"'),
#  (2,
#   '0.054*"world" + 0.026*"give" + 0.023*"form" + 0.023*"future" + '
#   '0.019*"present" + 0.018*"lose" + 0.018*"find" + 0.015*"sense" + '
#   '0.013*"hold" + 0.013*"person"'),
#  (3,
#   '0.037*"feel" + 0.034*"love" + 0.026*"sense" + 0.024*"emotional" + '
#   '0.021*"fear" + 0.020*"relationship" + 0.017*"experience" + 0.014*"feeling" '
#   '+ 0.013*"sensitive" + 0.013*"emotion"'),
#  (4,
#   '0.070*"sex" + 0.048*"sexual" + 0.015*"gay" + 0.013*"homosexual" + '
#   '0.011*"male" + 0.010*"scene" + 0.010*"sexually" + 0.009*"female" + '
#   '0.009*"rape" + 0.008*"bed"'),
#  (5,
#   '0.074*"murder" + 0.055*"mystery" + 0.035*"case" + 0.025*"suspect" + '
#   '0.021*"find" + 0.015*"police" + 0.015*"lead" + 0.014*"detective" + '
#   '0.014*"victim" + 0.013*"body"'),
#  (6,
#   '0.034*"time" + 0.034*"part" + 0.033*"good" + 0.027*"set" + 0.024*"give" + '
#   '0.024*"full" + 0.020*"number" + 0.018*"man" + 0.016*"wife" + 0.014*"bad"'),
#  (7,
#   '0.022*"author" + 0.011*"protagonist" + 0.010*"narrative" + '
#   '0.009*"experience" + 0.008*"fiction" + 0.007*"late" + 0.007*"portrayal" + '
#   '0.006*"conflict" + 0.006*"imagine" + 0.005*"fate"'),
#  (8,
#   '0.070*"good" + 0.060*"find" + 0.054*"make" + 0.054*"back" + 0.042*"friend" '
#   '+ 0.030*"give" + 0.027*"home" + 0.025*"bring" + 0.023*"run" + 0.022*"end"'),
#  (9,
#   '0.019*"kill" + 0.017*"plot" + 0.016*"turn" + 0.015*"steal" + 0.015*"shoot" '
#   '+ 0.011*"call" + 0.011*"hire" + 0.011*"gun" + 0.009*"lead" + 0.008*"cop"'),
#  (10,
#   '0.042*"write" + 0.036*"poet" + 0.022*"prose" + 0.022*"reader" + '
#   '0.021*"word" + 0.020*"language" + 0.020*"poetry" + 0.019*"style" + '
#   '0.017*"work" + 0.015*"make"'),
#  (11,
#   '0.117*"black" + 0.063*"white" + 0.021*"man" + 0.019*"slave" + 0.017*"color" '
#   '+ 0.016*"race" + 0.016*"southern" + 0.015*"african" + 0.014*"people" + '
#   '0.012*"negro"'),
#  (12,
#   '0.025*"secret" + 0.024*"plan" + 0.023*"agent" + 0.021*"spy" + 0.015*"plot" '
#   '+ 0.014*"action" + 0.013*"terrorist" + 0.013*"british" + 0.011*"kill" + '
#   '0.011*"thriller"'),
#  (13,
#   '0.015*"half" + 0.015*"page" + 0.015*"lot" + 0.015*"type" + 0.010*"funny" + '
#   '0.010*"finally" + 0.009*"style" + 0.009*"comic" + 0.008*"hero" + '
#   '0.008*"talk"'),
#  (14,
#   '0.022*"music" + 0.018*"hear" + 0.017*"eye" + 0.016*"call" + 0.015*"time" + '
#   '0.014*"wear" + 0.014*"voice" + 0.013*"long" + 0.013*"singer" + '
#   '0.012*"blue"'),
#  (15,
#   '0.025*"power" + 0.022*"fantasy" + 0.020*"evil" + 0.018*"tale" + '
#   '0.018*"ancient" + 0.016*"king" + 0.016*"great" + 0.014*"magic" + '
#   '0.014*"world" + 0.011*"legend"'),
#  (16,
#   '0.046*"leave" + 0.030*"child" + 0.029*"home" + 0.028*"move" + 0.028*"farm" '
#   '+ 0.027*"year" + 0.027*"wife" + 0.026*"return" + 0.025*"country" + '
#   '0.025*"live"'),
#  (17,
#   '0.047*"memory" + 0.035*"life" + 0.034*"death" + 0.029*"live" + '
#   '0.025*"childhood" + 0.022*"move" + 0.021*"die" + 0.017*"recall" + '
#   '0.017*"long" + 0.017*"loss"'),
#  (18,
#   '0.029*"lady" + 0.022*"young" + 0.022*"horse" + 0.015*"offer" + '
#   '0.012*"heroine" + 0.011*"turn" + 0.010*"bit" + 0.010*"friend" + '
#   '0.010*"find" + 0.009*"elderly"'),
#  (19,
#   '0.047*"american" + 0.036*"story" + 0.034*"rise" + 0.027*"japanese" + '
#   '0.027*"young" + 0.026*"woman" + 0.026*"world" + 0.023*"chinese" + '
#   '0.020*"learn" + 0.019*"bear"'),
#  (20,
#   '0.048*"book" + 0.028*"write" + 0.021*"deal" + 0.020*"scene" + 0.019*"word" '
#   '+ 0.015*"close" + 0.013*"small" + 0.012*"early" + 0.012*"kind" + '
#   '0.011*"world"'),
#  (21,
#   '0.258*"love" + 0.063*"fall" + 0.034*"marry" + 0.031*"young" + '
#   '0.030*"affair" + 0.029*"marriage" + 0.027*"meet" + 0.025*"lover" + '
#   '0.025*"passion" + 0.022*"romance"'),
#  (22,
#   '0.042*"point" + 0.033*"view" + 0.020*"society" + 0.020*"begin" + '
#   '0.020*"set" + 0.016*"author" + 0.015*"time" + 0.014*"remain" + '
#   '0.013*"provide" + 0.013*"high"'),
#  (23,
#   '0.031*"faith" + 0.029*"religious" + 0.026*"spiritual" + 0.024*"priest" + '
#   '0.020*"church" + 0.016*"religion" + 0.013*"catholic" + 0.010*"miracle" + '
#   '0.010*"sin" + 0.010*"soul"'),
#  (24,
#   '0.053*"character" + 0.020*"move" + 0.018*"offer" + 0.016*"work" + '
#   '0.016*"draw" + 0.014*"create" + 0.013*"portrait" + 0.012*"complex" + '
#   '0.012*"detail" + 0.011*"vivid"'),
#  (25,
#   '0.063*"make" + 0.053*"city" + 0.034*"side" + 0.033*"time" + 0.025*"catch" + '
#   '0.024*"heart" + 0.018*"back" + 0.018*"read" + 0.017*"end" + 0.017*"set"'),
#  (26,
#   '0.068*"man" + 0.024*"make" + 0.021*"follow" + 0.019*"great" + '
#   '0.017*"failure" + 0.016*"prove" + 0.016*"success" + 0.015*"lead" + '
#   '0.014*"hold" + 0.014*"build"'),
#  (27,
#   '0.057*"friend" + 0.051*"man" + 0.047*"make" + 0.039*"good" + 0.033*"talk" + '
#   '0.031*"true" + 0.028*"turn" + 0.025*"real" + 0.024*"love" + 0.023*"learn"'),
#  (28,
#   '0.021*"put" + 0.020*"head" + 0.018*"run" + 0.018*"back" + 0.018*"big" + '
#   '0.018*"call" + 0.013*"paper" + 0.013*"stand" + 0.012*"bad" + 0.011*"thing"'),
#  (29,
#   '0.029*"great" + 0.025*"good" + 0.025*"hand" + 0.024*"life" + 0.024*"long" + '
#   '0.020*"end" + 0.017*"give" + 0.017*"year" + 0.015*"lie" + 0.015*"real"'),
#  (30,
#   '0.038*"indian" + 0.026*"native" + 0.024*"land" + 0.019*"man" + '
#   '0.019*"mountain" + 0.013*"adventure" + 0.013*"western" + 0.013*"territory" '
#   '+ 0.012*"tribe" + 0.012*"people"'),
#  (31,
#   '0.039*"dog" + 0.031*"animal" + 0.024*"human" + 0.018*"wild" + 0.018*"bird" '
#   '+ 0.015*"fish" + 0.014*"tree" + 0.013*"cat" + 0.012*"author" + 0.012*"eat"'),
#  (32,
#   '0.064*"life" + 0.056*"time" + 0.042*"young" + 0.034*"change" + 0.032*"man" '
#   '+ 0.029*"find" + 0.029*"long" + 0.024*"offer" + 0.019*"lose" + '
#   '0.019*"couple"'),
#  (33,
#   '0.256*"woman" + 0.131*"man" + 0.067*"young" + 0.026*"husband" + '
#   '0.021*"life" + 0.020*"love" + 0.019*"female" + 0.016*"live" + 0.014*"age" + '
#   '0.012*"male"'),
#  (34,
#   '0.024*"historical" + 0.022*"history" + 0.020*"war" + 0.019*"fight" + '
#   '0.018*"british" + 0.017*"force" + 0.016*"battle" + 0.013*"spanish" + '
#   '0.012*"follow" + 0.011*"capture"'),
#  (35,
#   '0.109*"character" + 0.053*"plot" + 0.031*"reader" + 0.021*"real" + '
#   '0.020*"set" + 0.016*"scene" + 0.016*"long" + 0.015*"page" + 0.014*"make" + '
#   '0.011*"turn"'),
#  (36,
#   '0.066*"history" + 0.028*"early" + 0.022*"historical" + 0.018*"great" + '
#   '0.018*"figure" + 0.017*"year" + 0.016*"detail" + 0.015*"century" + '
#   '0.013*"event" + 0.013*"research"'),
#  (37,
#   '0.052*"make" + 0.040*"part" + 0.036*"question" + 0.030*"reader" + '
#   '0.026*"problem" + 0.021*"fact" + 0.021*"deal" + 0.019*"time" + '
#   '0.017*"prove" + 0.017*"provide"'),
#  (38,
#   '0.084*"war" + 0.034*"soldier" + 0.027*"officer" + 0.026*"man" + '
#   '0.019*"fight" + 0.016*"military" + 0.016*"battle" + 0.014*"action" + '
#   '0.011*"force" + 0.011*"wound"'),
#  (39,
#   '0.059*"dream" + 0.023*"ghost" + 0.019*"light" + 0.017*"gift" + '
#   '0.016*"vision" + 0.016*"haunt" + 0.013*"dark" + 0.013*"watch" + '
#   '0.011*"image" + 0.010*"mind"'),
#  (40,
#   '0.037*"story" + 0.035*"work" + 0.034*"writer" + 0.030*"author" + '
#   '0.021*"fiction" + 0.017*"young" + 0.014*"contemporary" + 0.013*"set" + '
#   '0.013*"develop" + 0.013*"subject"'),
#  (41,
#   '0.141*"boy" + 0.079*"girl" + 0.068*"young" + 0.032*"grow" + 0.029*"story" + '
#   '0.028*"summer" + 0.023*"age" + 0.022*"adult" + 0.018*"parent" + '
#   '0.017*"grace"'),
#  (42,
#   '0.029*"night" + 0.027*"live" + 0.026*"room" + 0.026*"day" + 0.024*"house" + '
#   '0.023*"apartment" + 0.018*"move" + 0.017*"work" + 0.016*"find" + '
#   '0.014*"job"'),
#  (43,
#   '0.255*"story" + 0.070*"collection" + 0.053*"tale" + 0.042*"piece" + '
#   '0.035*"short" + 0.031*"title" + 0.028*"short_storie" + 0.022*"good" + '
#   '0.019*"writer" + 0.011*"volume"'),
#  (44,
#   '0.052*"jewish" + 0.040*"german" + 0.028*"french" + 0.028*"escape" + '
#   '0.015*"group" + 0.014*"nazi" + 0.013*"camp" + 0.012*"refugee" + '
#   '0.011*"work" + 0.011*"russian"'),
#  (45,
#   '0.108*"time" + 0.089*"year" + 0.082*"day" + 0.050*"spend" + 0.046*"long" + '
#   '0.028*"back" + 0.025*"return" + 0.020*"month" + 0.018*"night" + '
#   '0.017*"week"'),
#  (46,
#   '0.052*"doctor" + 0.025*"hospital" + 0.025*"patient" + 0.020*"death" + '
#   '0.015*"nurse" + 0.015*"medical" + 0.013*"treatment" + 0.013*"cancer" + '
#   '0.012*"practice" + 0.010*"psychiatrist"'),
#  (47,
#   '0.045*"man" + 0.023*"death" + 0.017*"reality" + 0.012*"moral" + '
#   '0.009*"consciousness" + 0.009*"talent" + 0.009*"physical" + '
#   '0.008*"illusion" + 0.008*"style" + 0.008*"contemporary"'),
#  (48,
#   '0.050*"art" + 0.039*"work" + 0.035*"artist" + 0.023*"life" + 0.021*"paint" '
#   '+ 0.015*"famous" + 0.015*"painter" + 0.013*"age" + 0.012*"show" + '
#   '0.012*"late"'),
#  (49,
#   '0.070*"play" + 0.035*"game" + 0.019*"win" + 0.016*"big" + 0.016*"time" + '
#   '0.015*"end" + 0.014*"good" + 0.013*"player" + 0.011*"part" + 0.011*"team"'),
#  (50,
#   '0.012*"theme" + 0.012*"fiction" + 0.011*"dialogue" + 0.010*"involve" + '
#   '0.010*"narration" + 0.009*"ironic" + 0.009*"focus" + 0.009*"occasionally" + '
#   '0.009*"fact" + 0.008*"thin"'),
#  (51,
#   '0.034*"death" + 0.029*"violence" + 0.026*"fear" + 0.021*"horror" + '
#   '0.020*"kill" + 0.014*"hate" + 0.013*"dark" + 0.013*"force" + '
#   '0.013*"violent" + 0.012*"hope"'),
#  (52,
#   '0.077*"find" + 0.048*"search" + 0.023*"discover" + 0.022*"travel" + '
#   '0.021*"seek" + 0.020*"identity" + 0.018*"truth" + 0.017*"learn" + '
#   '0.016*"meet" + 0.015*"miss"'),
#  (53,
#   '0.055*"school" + 0.049*"student" + 0.040*"teacher" + 0.027*"college" + '
#   '0.026*"teach" + 0.024*"class" + 0.018*"professor" + 0.015*"year" + '
#   '0.014*"young" + 0.012*"friend"'),
#  (54,
#   '0.077*"story" + 0.060*"people" + 0.057*"village" + 0.033*"small" + '
#   '0.028*"life" + 0.023*"place" + 0.022*"author" + 0.022*"simple" + '
#   '0.022*"live" + 0.018*"country"'),
#  (55,
#   '0.084*"wife" + 0.066*"marriage" + 0.056*"husband" + 0.040*"daughter" + '
#   '0.030*"woman" + 0.028*"divorce" + 0.026*"leave" + 0.025*"affair" + '
#   '0.021*"life" + 0.019*"marry"'),
#  (56,
#   '0.112*"book" + 0.054*"character" + 0.047*"write" + 0.037*"author" + '
#   '0.030*"reader" + 0.026*"read" + 0.022*"theme" + 0.019*"part" + '
#   '0.018*"interesting" + 0.016*"style"'),
#  (57,
#   '0.141*"life" + 0.048*"people" + 0.047*"story" + 0.043*"live" + 0.028*"give" '
#   '+ 0.027*"bring" + 0.025*"end" + 0.016*"great" + 0.014*"year" + '
#   '0.012*"strange"'),
#  (58,
#   '0.037*"ship" + 0.023*"sea" + 0.023*"adventure" + 0.019*"island" + '
#   '0.018*"water" + 0.017*"man" + 0.016*"crew" + 0.015*"fly" + 0.014*"storm" + '
#   '0.013*"rescue"'),
#  (59,
#   '0.064*"write" + 0.043*"writer" + 0.031*"literary" + 0.031*"publish" + '
#   '0.027*"book" + 0.023*"letter" + 0.021*"fiction" + 0.020*"author" + '
#   '0.019*"editor" + 0.018*"early"'),
#  (60,
#   '0.112*"child" + 0.075*"mother" + 0.044*"baby" + 0.034*"love" + '
#   '0.031*"daughter" + 0.028*"pregnant" + 0.025*"bear" + 0.023*"girl" + '
#   '0.021*"marry" + 0.021*"die"'),
#  (61,
#   '0.045*"brother" + 0.034*"set" + 0.031*"save" + 0.022*"lose" + '
#   '0.022*"return" + 0.022*"escape" + 0.021*"turn" + 0.018*"rescue" + '
#   '0.017*"stone" + 0.015*"gold"'),
#  (62,
#   '0.112*"book" + 0.042*"story" + 0.024*"read" + 0.023*"quality" + '
#   '0.019*"picture" + 0.018*"market" + 0.018*"appeal" + 0.014*"reader" + '
#   '0.013*"sell" + 0.012*"people"'),
#  (63,
#   '0.023*"drug" + 0.020*"good" + 0.020*"bad" + 0.018*"run" + 0.018*"hard" + '
#   '0.017*"kid" + 0.016*"beat" + 0.013*"car" + 0.013*"drink" + 0.012*"job"'),
#  (64,
#   '0.041*"money" + 0.035*"business" + 0.027*"job" + 0.019*"sell" + '
#   '0.019*"company" + 0.017*"big" + 0.017*"pay" + 0.014*"firm" + 0.013*"price" '
#   '+ 0.012*"make"'),
#  (65,
#   '0.041*"return" + 0.040*"begin" + 0.033*"year" + 0.032*"meet" + 0.030*"find" '
#   '+ 0.029*"finally" + 0.022*"home" + 0.021*"eventually" + 0.019*"learn" + '
#   '0.018*"lose"'),
#  (66,
#   '0.219*"family" + 0.057*"son" + 0.044*"daughter" + 0.031*"brother" + '
#   '0.018*"generation" + 0.017*"die" + 0.016*"member" + 0.014*"marry" + '
#   '0.013*"live" + 0.011*"year"'),
#  (67,
#   '0.024*"funny" + 0.023*"humor" + 0.021*"comedy" + 0.020*"comic" + '
#   '0.014*"amusing" + 0.012*"witty" + 0.011*"sort" + 0.011*"entertain" + '
#   '0.010*"eccentric" + 0.010*"good"'),
#  (68,
#   '0.051*"thing" + 0.045*"world" + 0.044*"make" + 0.042*"people" + '
#   '0.034*"feel" + 0.025*"eye" + 0.024*"reader" + 0.021*"real" + 0.019*"place" '
#   '+ 0.018*"live"'),
#  (69,
#   '0.046*"murder" + 0.030*"case" + 0.027*"lawyer" + 0.027*"kill" + '
#   '0.024*"trial" + 0.023*"prison" + 0.018*"charge" + 0.016*"arrest" + '
#   '0.015*"crime" + 0.013*"law"'),
#  (70,
#   '0.132*"story" + 0.031*"background" + 0.028*"period" + 0.028*"good" + '
#   '0.023*"picture" + 0.020*"romance" + 0.015*"adventure" + 0.014*"bit" + '
#   '0.014*"interest" + 0.013*"pattern"'),
#  (71,
#   '0.078*"death" + 0.072*"dead" + 0.060*"die" + 0.031*"leave" + 0.031*"body" + '
#   '0.026*"kill" + 0.022*"man" + 0.020*"turn" + 0.019*"blood" + 0.016*"face"'),
#  (72,
#   '0.091*"life" + 0.039*"work" + 0.022*"friend" + 0.022*"social" + '
#   '0.021*"character" + 0.019*"draw" + 0.017*"show" + 0.017*"scene" + '
#   '0.017*"make" + 0.016*"lack"'),
#  (73,
#   '0.016*"world" + 0.015*"audience" + 0.014*"experience" + 0.012*"finally" + '
#   '0.010*"special" + 0.010*"attempt" + 0.010*"young" + 0.009*"charm" + '
#   '0.008*"achieve" + 0.008*"assure"'),
#  (74,
#   '0.035*"time" + 0.029*"high" + 0.025*"bad" + 0.024*"thing" + 0.022*"start" + '
#   '0.017*"turn" + 0.016*"fall" + 0.016*"find" + 0.015*"back" + 0.015*"pretty"'),
#  (75,
#   '0.063*"political" + 0.020*"country" + 0.019*"politic" + 0.016*"government" '
#   '+ 0.016*"state" + 0.013*"power" + 0.012*"personal" + 0.012*"journalist" + '
#   '0.010*"american" + 0.010*"revolutionary"'),
#  (76,
#   '0.141*"mother" + 0.081*"family" + 0.045*"sister" + 0.036*"father" + '
#   '0.035*"parent" + 0.032*"daughter" + 0.031*"child" + 0.016*"brother" + '
#   '0.016*"home" + 0.016*"girl"'),
#  (77,
#   '0.036*"find" + 0.027*"face" + 0.023*"force" + 0.021*"problem" + '
#   '0.020*"bring" + 0.019*"attempt" + 0.017*"wife" + 0.016*"issue" + '
#   '0.016*"make" + 0.014*"conflict"'),
#  (78,
#   '0.028*"human" + 0.022*"earth" + 0.018*"world" + 0.016*"future" + '
#   '0.013*"space" + 0.013*"planet" + 0.012*"idea" + 0.012*"computer" + '
#   '0.012*"scientist" + 0.012*"machine"'),
#  (79,
#   '0.070*"narrator" + 0.046*"story" + 0.024*"work" + 0.024*"voice" + '
#   '0.023*"piece" + 0.022*"describe" + 0.021*"narrative" + 0.020*"fiction" + '
#   '0.015*"writer" + 0.015*"tale"')]

# %%
def format_topics_sentences(ldamodel=lda_model, corpus=corpus, texts=data):
# Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row in enumerate(ldamodel[corpus]):
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(ldamodel=optimal_model, corpus=corpus, texts=data)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']

# Show
df_dominant_topic.head(10)
# Out:
#    Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0            0            78.0              0.2212
# 1            1            50.0              0.1249
# 2            2            31.0              0.1069
# 3            3            12.0              0.1185
# 4            4            12.0              0.1190
# 5            5             5.0              0.0316
# 6            6            12.0              0.1161
# 7            7            64.0              0.0540
# 8            8            13.0              0.0872
# 9            9             9.0              0.1201
#
#                                             Keywords  \
# 0  human, earth, world, future, space, planet, id...
# 1  theme, fiction, dialogue, involve, narration, ...
# 2  dog, animal, human, wild, bird, fish, tree, ca...
# 3  secret, plan, agent, spy, plot, action, terror...
# 4  secret, plan, agent, spy, plot, action, terror...
# 5  murder, mystery, case, suspect, find, police, ...
# 6  secret, plan, agent, spy, plot, action, terror...
# 7  money, business, job, sell, company, big, pay,...
# 8  half, page, lot, type, funny, finally, style, ...
# 9  kill, plot, turn, steal, shoot, call, hire, gu...
#
#                                                 Text
# 0  An addition to Asimov's series of robot-detect...
# 1  It's certainly possible to get inside the head...
# 2  A book that may owe its existence to a certain...
# 3  Mock-camp spy thriller set in the Spanish Civi...
# 4  This leisurely, episodic thriller eventually l...
# 5  Another Hercule Poirot story; setting a big "d...
# 6  One woman's attempt to assassinate an East Ger...
# 7  Patrick returns to the scene of his first lite...
# 8  Best known for his zingy Fletch mysteries, Mcd...
# 9  First novel about a New York private eye and s...

# %%
df_dominant_topic.to_csv('dominant_topic_for_each_review.csv')
